# %%
from datetime import datetime
from vortexasdk import CargoMovements

# %%
dt = datetime(2017, 8, 1)

# %%
CargoMovements().search(filter_activity='loading_state', filter_time_min=dt, filter_time_max=dt).to_df()
# Out:
# 2020-04-20 13:22:16,654 vortexasdk.operations — INFO — Searching CargoMovements with params: {'filter_activity': 'loading_state', 'filter_time_min': '2017-08-01T00:00:00.000Z', 'filter_time_max': '2017-08-01T00:00:00.000Z', 'timeseries_activity_time_span_min': None, 'timeseries_activity_time_span_max': None, 'cm_unit': 'b', 'filter_charterers': [], 'filter_owners': [], 'filter_products': [], 'filter_vessels': [], 'filter_destinations': [], 'filter_origins': [], 'filter_storage_locations': [], 'filter_ship_to_ship_locations': [], 'filter_waypoints': [], 'disable_geographic_exclusion_rules': None, 'size': 500}
# Loading from API:   0%|          | 0/836 [00:00<?, ?it/s]
# 2020-04-20 13:22:20,573 vortexasdk.client — INFO — 836 Results to retreive. Sending 2 post requests in parallel using 6 threads.
# Loading from API: 1000it [00:01, 539.40it/s]
#     events.cargo_port_load_event.0.location.port.label  \
# 0                                      Ras Gharib [EG]
# ...
